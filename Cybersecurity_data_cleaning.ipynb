# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os

# %%
df= pd.read_csv("cybersecurity_attacks.csv")

# %%
df
# Out:
#                  Timestamp Source IP Address Destination IP Address  \
# 0      2023-05-30 06:33:58     103.216.15.12           84.9.164.252
# 1      2020-08-26 07:08:30    78.199.217.198         66.191.137.154
# 2      2022-11-13 08:23:25      63.79.210.48          198.219.82.17
# 3      2023-07-02 10:38:46     163.42.196.10        101.228.192.255
# 4      2023-07-16 13:11:07     71.166.185.76        189.243.174.238
# ...                    ...               ...                    ...
# 39995  2023-05-26 14:08:42      26.36.109.26         121.100.75.240
# 39996  2023-03-27 00:38:27      17.21.163.81         196.108.134.78
# 39997  2022-03-31 01:45:49     162.35.217.57            98.107.0.15
# 39998  2023-09-22 18:32:38    208.72.233.205         173.79.112.252
# 39999  2023-10-10 11:59:52     14.102.21.108           109.198.45.7
#
#        Source Port  Destination Port Protocol  Packet Length Packet Type  \
# 0            31225             17616     ICMP            503        Data
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp                     0
# Source IP Address             0
# Destination IP Address        0
# Source Port                   0
# Destination Port              0
# Protocol                      0
# Packet Length                 0
# Packet Type                   0
# Traffic Type                  0
# Payload Data                  0
# Malware Indicators        20000
# Anomaly Scores                0
# Alerts/Warnings           20067
# Attack Type                   0
# Attack Signature              0
# Action Taken                  0
# Severity Level                0
# User Information              0
# Device Information            0
# Network Segment               0
# Geo-location Data             0
# Proxy Information         19851
# Firewall Logs             19961
# IDS/IPS Alerts            20050
# Log Source                    0
# dtype: int64

# %%
df.dropna(how="all")
# Out:
#                  Timestamp Source IP Address Destination IP Address  \
# 0      2023-05-30 06:33:58     103.216.15.12           84.9.164.252
# 1      2020-08-26 07:08:30    78.199.217.198         66.191.137.154
# 2      2022-11-13 08:23:25      63.79.210.48          198.219.82.17
# 3      2023-07-02 10:38:46     163.42.196.10        101.228.192.255
# 4      2023-07-16 13:11:07     71.166.185.76        189.243.174.238
# ...                    ...               ...                    ...
# 39995  2023-05-26 14:08:42      26.36.109.26         121.100.75.240
# 39996  2023-03-27 00:38:27      17.21.163.81         196.108.134.78
# 39997  2022-03-31 01:45:49     162.35.217.57            98.107.0.15
# 39998  2023-09-22 18:32:38    208.72.233.205         173.79.112.252
# 39999  2023-10-10 11:59:52     14.102.21.108           109.198.45.7
#
#        Source Port  Destination Port Protocol  Packet Length Packet Type  \
# 0            31225             17616     ICMP            503        Data
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp                     0
# Source IP Address             0
# Destination IP Address        0
# Source Port                   0
# Destination Port              0
# Protocol                      0
# Packet Length                 0
# Packet Type                   0
# Traffic Type                  0
# Payload Data                  0
# Malware Indicators        20000
# Anomaly Scores                0
# Alerts/Warnings           20067
# Attack Type                   0
# Attack Signature              0
# Action Taken                  0
# Severity Level                0
# User Information              0
# Device Information            0
# Network Segment               0
# Geo-location Data             0
# Proxy Information         19851
# Firewall Logs             19961
# IDS/IPS Alerts            20050
# Log Source                    0
# dtype: int64

# %%
df1=df.fillna({
    'Malware Indicators':'IoC Not Detected',
    'Alerts/Warnings':'No Warning',
    'Proxy Information':'Unspecified',
    'Firewall Logs':'No Data',
    'IDS/IPS Alerts':'No Alert Data'
})

# %%
df1
# Out:
#                  Timestamp Source IP Address Destination IP Address  \
# 0      2023-05-30 06:33:58     103.216.15.12           84.9.164.252
# 1      2020-08-26 07:08:30    78.199.217.198         66.191.137.154
# 2      2022-11-13 08:23:25      63.79.210.48          198.219.82.17
# 3      2023-07-02 10:38:46     163.42.196.10        101.228.192.255
# 4      2023-07-16 13:11:07     71.166.185.76        189.243.174.238
# ...                    ...               ...                    ...
# 39995  2023-05-26 14:08:42      26.36.109.26         121.100.75.240
# 39996  2023-03-27 00:38:27      17.21.163.81         196.108.134.78
# 39997  2022-03-31 01:45:49     162.35.217.57            98.107.0.15
# 39998  2023-09-22 18:32:38    208.72.233.205         173.79.112.252
# 39999  2023-10-10 11:59:52     14.102.21.108           109.198.45.7
#
#        Source Port  Destination Port Protocol  Packet Length Packet Type  \
# 0            31225             17616     ICMP            503        Data
# ...

# %%
df1.to_csv("cybersecurity_attacks_new.csv", index= False)

# %%
import pandas as pd
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
def clean_text(text):
    if text is None:
        return ""
    text = text.lower()
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    tokens = word_tokenize(text)
    stop_words = set(stopwords.words("english"))
    filtered_tokens = [word for word in tokens if word not in stop_words]
    cleaned_text = " ".join(filtered_tokens)
    return cleaned_text

# %%
df["Payload Data Cleaned"] = df["Payload Data"].apply(clean_text)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df["Payload Data Cleaned"] = df["Payload Data"].apply(clean_text)
#
# File ~\Documents\Custom Office Templates\lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\Documents\Custom Office Templates\lib\site-packages\pandas\core\apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# ...
